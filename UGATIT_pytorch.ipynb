# %% [markdown]
# <a href="https://colab.research.google.com/github/ETSlime/GoogleColab/blob/UGATIT/UGATIT_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/My Drive/
# Out:
# /content/drive/My Drive

# %%
# !git clone https://github.com/znxlwm/UGATIT-pytorch.git
# Out:
# Cloning into 'UGATIT-pytorch'...
# remote: Enumerating objects: 70, done.
# remote: Total 70 (delta 0), reused 0 (delta 0), pack-reused 70
# Unpacking objects: 100% (70/70), done.

# %%
import os
os.chdir('UGATIT-pytorch/')

# %%
# !pip install dominate
# !pip install visdom
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 676 kB 14.8 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.2 MB/s
# ...
#   Created wheel for visdom: filename=visdom-0.1.8.9-py3-none-any.whl size=655250 sha256=913287d0a369fb6b5d0dc21e3f8368a17d6826a8921858b28d6d24c0e3613372
#   Stored in directory: /root/.cache/pip/wheels/2d/d1/9b/cde923274eac9cbb6ff0d8c7c72fe30a3da9095a38fd50bbf1
# ...
#   Created wheel for torchfile: filename=torchfile-0.1.0-py3-none-any.whl size=5709 sha256=a80daaee2d1443c9732d7da541b625c15ffa7da7b1da662d735c7e0bb3459181
#   Stored in directory: /root/.cache/pip/wheels/ac/5c/3a/a80e1c65880945c71fd833408cd1e9a8cb7e2f8f37620bb75b
# Successfully built visdom torchfile
# ...
#      |████████████████████████████████| 1.7 MB 15.1 MB/s
# ...
#      |████████████████████████████████| 144 kB 64.6 MB/s
# ...
#      |████████████████████████████████| 181 kB 59.6 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.2 MB/s
# ...

# %%
# !python main.py --name selfie2anime_cam --dataset selfie2anime --batch_size 1 --light True --iteration 50000 --print_freq 100 --use_wandb
# Out:
# Streaming output truncated to the last 5000 lines.
# [45033/50000] time: 25018.9404 d_loss: 1.54928839, g_loss: 9.39546585
# [45034/50000] time: 25019.3966 d_loss: 2.25732040, g_loss: 24.88421822
# [45035/50000] time: 25019.8558 d_loss: 1.95894206, g_loss: 12.18003750
# [45036/50000] time: 25020.3212 d_loss: 1.45467663, g_loss: 17.30755424
# [45037/50000] time: 25020.7884 d_loss: 1.38202667, g_loss: 17.08849525
# [45038/50000] time: 25021.2508 d_loss: 2.05065227, g_loss: 14.89273739
# [45039/50000] time: 25021.7058 d_loss: 2.26082420, g_loss: 39.46495819
# [45040/50000] time: 25022.1629 d_loss: 3.01187205, g_loss: 866.48681641
# [45041/50000] time: 25022.6258 d_loss: 1.39331365, g_loss: 16.48268318
# [45042/50000] time: 25023.0843 d_loss: 2.12345266, g_loss: 13.12262154
# [45043/50000] time: 25023.5404 d_loss: 2.32487154, g_loss: 213.97143555
# [45044/50000] time: 25024.0125 d_loss: 1.71253610, g_loss: 12.87574005
# ...

# %%
# !python main.py --name horse2zebra_cam_test --dataset horse2zebra --phase test
# Out:
# number of epochs must be larger than or equal to one
# Setting up a new session...
# create web directory ./checkpoints/horse2zebra_cam_test/web...
#
# ##### Information #####
# # light :  False
# # dataset :  horse2zebra
# # batch_size :  1
# # iteration per epoch :  1000000
#
# ##### Generator #####
# # residual blocks :  4
#
# ##### Discriminator #####
# # discriminator layer :  6
#
# ##### Weight #####
# # adv_weight :  1
# # cycle_weight :  10
# # identity_weight :  10
# # cam_weight :  1000
# ...

# %%
# !python main.py --name iphone2dslr_flower_cam_test --dataset iphone2dslr_flower --batch_size 1 --light True --iteration 20005 --print_freq 1 --resume true --use_wandb
# Out:
# number of epochs must be larger than or equal to one
# Setting up a new session...
# wandb: Currently logged in as: etslime (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.11
# wandb: Run data is saved locally in /content/drive/MyDrive/UGATIT-pytorch/wandb/run-20220327_211000-xyc55xpv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run iphone2dslr_flower_cam_test
# wandb: ⭐️ View project at https://wandb.ai/etslime/CycleGAN-and-pix2pix
# wandb: 🚀 View run at https://wandb.ai/etslime/CycleGAN-and-pix2pix/runs/xyc55xpv
# create web directory ./checkpoints/iphone2dslr_flower_cam_test/web...
#
# ##### Information #####
# # light :  True
# # dataset :  iphone2dslr_flower
# # batch_size :  1
# # iteration per epoch :  20005
#
# ##### Generator #####
# # residual blocks :  4
#
# ##### Discriminator #####
# # discriminator layer :  6
#
# ##### Weight #####
# # adv_weight :  1
# # cycle_weight :  10
# # identity_weight :  10
# ...
